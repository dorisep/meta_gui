# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
import csv

# %%
meta_score_df  = pd.read_csv('clean_meta_scrape.csv', encoding = 'UTF')
meta_score_df.tail()
# Out:
#               album                          artist               date  \
# 95   Raise The Roof  Robert Plant And Alison Krauss  November 19, 2021
# 96               30                           Adele  November 19, 2021
# 97  Stomping Ground                            Dion  November 19, 2021
# 98   Flying Dream 1                           Elbow  November 19, 2021
# 99     Bloodmoon: I                        Converge  November 19, 2021
#
#     week_num  meta_score user_score
# 95        46          82         87
# 96        46          88         86
# 97        46          69        tbd
# 98        46          83         72
# 99        46          89         73

# %%
meta_score_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   album       100 non-null    object
#  1   artist      100 non-null    object
#  2   date        100 non-null    object
#  3   week_num    100 non-null    int64
#  4   meta_score  100 non-null    int64
#  5   user_score  100 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 4.8+ KB

# %%
meta_score_df.loc[meta_score_df['meta_score'] >= 80]
# Out:
#                                                 album  \
# 1                                         Laurel Hell
# 2                                  Ants From Up There
# 5                                           Godmother
# 6                                     AnaÃ¯s Mitchell
# 14                                             Aboogi
# 17                                       In Free Fall
# 19                                       The Overload
# 20                              The Gods We Can Touch
# 25                                                  W
# 32                                           Optimism
# 34                                      Ghost Stories
# 38                                   The Boy Named If
# 40                               Caprisongs [Mixtape]
# 41                                              Sick!
# 50                                            Dawn FM
# 53                                      Antidawn [EP]
# ...

# %%
mask = meta_score_df

# %%
mask = meta_score_df

# %%
mask = meta_score_df
